# %%
# %pip install transformers langdetect deep-translator torch torchvision torchaudio langchain langchain-community langchain-ollama gradio -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 25.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 66.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 51.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 MB 9.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.1/320.1 kB 22.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.5/409.5 kB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.2/11.2 MB 45.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 55.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.8/63.8 kB 2.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 7.6 MB/s eta 0:00:00
#   Building wheel for langdetect (setup.py) ... done

# %%
from langchain_ollama import ChatOllama
from langchain.prompts import PromptTemplate

# %%
template = """
You're a native internal AI assistant. Help users with their important tasks, like a professor in a particular field.

Query: {query}
"""

# %%
prompt = PromptTemplate(
    input_variables = ["query"],
    template = template
)

# %%
model_name = "mistral"
llm = ChatOllama(
    base_url="http://216.48.181.46:11434",
    temperature = 0,
    max_tokens = 2000,
    model = model_name
)

# %%
chain = prompt | llm

# %%
from langdetect import detect
from deep_translator import GoogleTranslator

# %%
class Translation:
  def __init__(self, text, destination):
    self.text = text
    self.destination = destination

    try:
      self.original = detect(self.text)
    except Exception as error:
      print(f"Error Occurred, Details : {error}")
      self.original = "auto"

  def translate(self):
    translator = GoogleTranslator(source=self.original, target=self.destination)
    translation = translator.translate(self.text)

    return translation

# %%
import gradio as gr

# %%
def reply(message, history):
  txt = Translation(message, "en")

  if txt.original == "en":
    response = chain.invoke({
        "query": message
    })

    return response
  else:
    translation = txt.translate()

    response = chain.invoke({
        "query": translation
    })

    t = Translation(response.content, txt.original)
    final_response = t.translate()

    return final_response

# %%
question = "What is Deep Learning?"

result = reply(question, history = [])

# %%
result.content
# Out:
# ' Deep Learning is a subset of Machine Learning (ML) that is based on artificial neural networks with representation learning. It takes inspiration from the structure and function of the brain\'s neurons to solve complex problems. The "deep" in deep learning refers to the number of layers between the input and output layers, which can be quite large, allowing the model to learn increasingly abstract features of the data as it moves through the network.\n\nDeep Learning models are particularly effective at tasks such as image and speech recognition, natural language processing, and game playing, among others. They have been instrumental in driving advancements in AI and automation across various industries.'

# %%
question = "ரியல் எஸ்டேட்டில் அதிக பணம் சம்பாதிப்பது எப்படி?"

result = reply(question, history = [])

result
# Out:
# 'ரியல் எஸ்டேட்டில் அதிக பணம் சம்பாதிக்க, பின்வரும் உத்திகளைக் கவனியுங்கள்:\n\n1. மதிப்பிழந்த சொத்துக்களில் முதலீடு செய்யுங்கள்: இருப்பிடம், நிலை அல்லது சந்தைப் போக்குகள் போன்ற காரணிகளால் சந்தை மதிப்புக்குக் குறைவான விலையில் உள்ள சொத்துக்களைத் தேடுங்கள். இந்த பண்புகள் காலப்போக்கில் குறிப்பிடத்தக்க மதிப்பீட்டிற்கான சாத்தியக்கூறுகளைக் கொண்டுள்ளன.\n\n2. வாடகை சொத்துக்களை வாங்கி வைத்திருங்கள்: வருமானம் தரும் சொத்துக்களை வாங்கி குத்தகைதாரர்களுக்கு வாடகைக்
களுடன் நெட்வொர்க்கிங் செய்வதிலும் நேரத்தை முதலீடு செய்யுங்கள். இந்த அறிவும் இணைப்புகளும் தகவலறிந்த முதலீட்டு முடிவுகளை எடுக்கவும் சாத்தியமான வாய்ப்புகளை அடையாளம் காணவும் உதவும்.\n\n9. பல்வகைப்படுத்தல்: உங்கள் அனைத்து முட்டைகளையும் ஒரே கூடையில் வைக்க வேண்டாம். பல்வேறு வகையான சொத்துக்கள், இருப்பிடங்கள் மற்றும் உத்திகள் ஆகியவற்றில் உங்கள் முதலீடுகளைப் பரப்புங்கள்.\n\n10. நீண்ட காலக் கண்ணோட்டம்: ரியல் எஸ்டேட் என்பது நீண்ட கால முதலீடு, எனவே பொறுமையாக இருங்கள் மற்றும் விரைவான லாபம் ஈட்டுவதை விட காலப்போக்கில் செல்வத்தை கட்டியெழுப்புவதில் கவனம் செலுத்துங்கள்.'

# %%
question = "do you know about spider-man?"

result = reply(question, history = [])

result
# Out:
# AIMessage(content=' Yes, I can certainly provide information about Spider-Man! He is a fictional superhero appearing in American comic books published by Marvel Comics. The character was created by writer-editor Stan Lee and writer-artist Steve Ditko. He first appeared in the anthology comic book Amazing Fantasy #15 (August 1962) in the Silver Age of Comic Books.\n\nSpider-Man\'s most well-known characteristic is his ability to adhere to surfaces, which enables him to scale walls and ceilings. He was given these abilities after a bite from a genetically altered super-spider during a field trip. Besides his agility, Spider-Man\'s reflexes are enhanced, his senses are keener than those of a human, he can withstand physical trauma that would be lethal to a normal human, and he has a "Spider-Sense" that warns him of danger.\n\nThe character was introduced during the height of the Cold War; Lee and Ditko conceived of Spider-Man as a counterpoint to the brooding superheroes of the time, such as Batman, and instead focused on a more lighthearted, teenage and socially relevant hero. Spider-Man is one of the most popular and commercially successful characters in American comic books.\n\nSpider-Man has been adapted into various animated and live-action television shows, movies, video games, and other media. The character has also appeared in numerous merchandise, including toys, clothing, and collectibles. In the Marvel Cinematic Universe, Spider-Man is portrayed by Tom Holland.\n\nIs there anything specific you would like to know about Spider-Man? I\'d be happy to help!', additional_kwargs={}, response_metadata={'model': 'mistral', 'created_at': '2024-11-29T11:27:45.562119033Z', 'done': True, 'done_reason': 'stop', 'total_duration': 7514459067, 'load_duration': 16238796, 'prompt_eval_count': 42, 'prompt_eval_duration': 4000000, 'eval_count': 379, 'eval_duration': 7491000000, 'message': Message(role='assistant', content='', images=None, tool_calls=None)}, id='run-67965239-be3f-4c3b-b722-d409495fa637-0', usage_metadata={'input_tokens': 42, 'output_tokens': 379, 'total_tokens': 421})

# %%
demo = gr.ChatInterface(fn=reply, title = "Multi-Lingual ChatBot")

demo.launch(debug=False, share=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/gradio/components/chatbot.py:243: UserWarning: The 'tuples' format for chatbot messages is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#   warnings.warn(
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://027568f6be7eda7a2e.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://027568f6be7eda7a2e.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
